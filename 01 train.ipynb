# %% [markdown]
# # 01 Train
#
# Train with `originbot_train.py`, then export ONNX with `originbot_onnx.py`.

# %%
from pathlib import Path

project_dir = Path.cwd()
dataset_dir = project_dir / "image_dataset"
dataset_dir_2 = project_dir / "image_dataset_0424"
print("project_dir:", project_dir)
print("dataset_dir:", dataset_dir)
print("dataset_exists:", dataset_dir.is_dir())
print("dataset_dir_2:", dataset_dir_2)
print("dataset_2_exists:", dataset_dir_2.is_dir())

# %%
# !python originbot_train.py --dataset-dir ./image_dataset --dataset-dir ./image_dataset_0424 --epochs 100 --batch-size 64 --num-workers 0 --val-every 3 --disable-channels-last

# %%
# !python originbot_onnx.py

# %%
from pathlib import Path

pth_path = Path("best_line_follower_model_xy.pth")
onnx_path = Path("best_line_follower_model_xy.onnx")
print("pth_exists:", pth_path.is_file(), pth_path)
print("onnx_exists:", onnx_path.is_file(), onnx_path)
